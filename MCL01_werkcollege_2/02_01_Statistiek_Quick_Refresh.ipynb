# %% [markdown]
# # Statistiek 101
#
# Enkele oefeningen om de statistiek (weer)op te halen.
#
# 1. Data types
# 2. Basis statstiek: gemiddelde (mean), mediaan en mode
# 3. Standaard deviatie
# 4. optioneel: Data distributies
#
# #### Wat ga je doen?
# Doorloop en voeruit (*Run* of *Shift+Enter*) de Python voorbeelden en doe de opdrachten. Kijk niet te snel in de voorbeeldoplossingen notebook, maar probeer eerst alles zelf op te lossen.
#
# ---

# %%
# print library versions
import platform, sys
import numpy as np
import scipy as sp

print(f"Python: {platform.platform()}, version:{sys.version[0:6]}")
print(f"numpy version: {np.__version__}")
print(f"scipy version: {sp.__version__}")
# Out:
# Python: Windows-10-10.0.26100-SP0, version:3.11.9
# numpy version: 2.3.4
# scipy version: 1.16.3

# %% [markdown]
# ---
# ## 1. Data types
#
# Je hebt een inzicht nodig in data/gegevens, omdat je er **verschillende soorten gegevens** zijn en het uitgangspunt van machine learning is **data**.
#
# Basis soorten gegevens zijn de volgende:
# - numeriek (*numerical*)
# - categorisch (*categorical*)
# - ranggetal (*ordinal*)

# %% [markdown]
# ### Numerieke data (*numerical*)
#
# - kwantitative gegevens
# - discrete gegevens:
# > - gehele getallen, zoals bijvoorbeeld: hoeveel bestellingen heeft een klant gedaan in een jaar?
# - continue gegevens:
# > - hoeveel tijd koste het een klant om een product te kopen?
# > - hoeveel regen valt er op een dag?
#
# ![](images/temperature.png)

# %% [markdown]
# ### Categorische data (*categorical*)
#
# - kwalitatieve gegevens die geen (inherente) wiskundige betekenis hebben:
# > - geslacht (M/V/X..),
# > - yes/no (binaire data),
# > - product categorie,
# > - politieke partij,
# > - provincie waarin je woont
# - je kunt nummers aan categorieën toewijzen om ze, bijvoorbeeld, compacter weer te geven, maar de getallen hebben geen wiskundige betekenis
#
# ![](images/ned_prov.png)

# %% [markdown]
# ### Rang/schaal data (*ordinal*)
#
# - mix van numerieke en categorische gegevens.
# - categorische data dat wel een (wiskundige)betekenis heeft:
# > - beoordelingen (*ratings*), bijvoorbeeld film beoordelingen in de vorm van aantal sterren
# > - beoordelingen zijn 1, 2, 3, 4 of 5. Elk van deze getallen heeft wel een betekenis: 2 betekent dat het een betere film is dan een 1, etc.
#
# ![](images/stars.png)

# %% [markdown]
# ### Quiz/oefening
#
# Zijn de volgende soorten gegevens *numerical*, *categorical* of *ordinal*? (6 examples)

# %% [markdown]
# #### 1. De hoeveelheid benzine in de benzinetank van jouw auto.

# %% [markdown]
# numeriek, continous data (elk getal ook al zit er een maximum aan).

# %% [markdown]
# #### 2. Inschatten van jouw algehele gezondheid op een schaal van 1 tot 4, waarbij 1 is slecht, 2 is matig, 3 is goed en 4 is uitstekend.

# %% [markdown]
# ordinal

# %% [markdown]
# #### 3. De nationaliteiten van alle afstudeerders.

# %% [markdown]
# categorical (je kan ze niet met elkaar vergelijken in de wiskundige betekenis)

# %% [markdown]
# #### 4. De leeftijden van je klasgenoten.

# %% [markdown]
# numerical, continuous data

# %% [markdown]
# #### 5. Het geld dat je uitgegeven hebt in een winkel.

# %% [markdown]
# numerical, continuous data

# %% [markdown]
# #### 6. Het aantal studenten in deze klas.

# %% [markdown]
# numeric, discrete data, je kan immers geen 'halve' of 'kwart' student hebben.

# %% [markdown]
# #### Interessante discussie op StackOverFlow:
# __[What is the difference between discrete data and continuous data?](https://stats.stackexchange.com/questions/206/what-is-the-difference-between-discrete-data-and-continuous-data)__

# %% [markdown]
# ---
# ## 2. Basis statistiek: gemiddelde (Mean), mediaan (Median) en Mode.

# %% [markdown]
# ### Mean (gemiddelde)
#
# - `mean` is het gemiddelde van een aantal gegevens (numerical, discrete)
#
# **Voorbeeld**
# Het aantal kinderen per huis in de buurt: 0, 2, 3, 2, 1, 0, 0, 2, 0
#
# Bereken het gemiddeld aantal kinderen per huis.

# %% [markdown]
# Gemiddelde (mean): (0+2+3+2+1+0+0+2+0) / 9 = 1.11

# %%
mean = (0+2+3+2+1+0+0+2+0) / 9
mean
# Out:
# 1.1111111111111112

# %% [markdown]
# ### Median
#
# - `median` is de waarde van het middelste getal in de (numeriek)gesorteerde gegevens
#
# **Voorbeeld**
# Het aantal kinderen per huis in de buurt: 0, 2, 3, 2, 1, 0, 0, 2, 0
#
# Bereken de mediaan (median)?

# %% [markdown]
# **Median**
# - originele reeks:   0,2,3,2,1,0,0,2,0
# - gesorteerde reeks: 0,0,0,0,1,2,2,2,3
# - median: 1 (middelste waarde)
#
# NB. Bij een *even* aantal getallen: median is gemiddelde van de middelste getallen
#
# De median is minder gevoelig voor *outliers*, ofwel uitschieters.

# %% [markdown]
# ### Mode
# - `mode` is de meest voorkomende waarde in de dataset.
# > - niet relevant voor continu numerieke gegevens
#
# **Voorbeeld**
# Het aantal kinderen per huis in de buurt: 0, 2, 3, 2, 1, 0, 0, 2, 0
#
# Bereken de mode.

# %% [markdown]
# **Mode**
# - hoeveel keer komt elke waarde voor:<br>
# 0: 4, 1: 1, 2: 3, 3: 1
# - -> mode: 0

# %% [markdown]
# ---
# ## Oefening Mean vs. Median
#
# Laten we een kunstmatige inkomensgegevens maken, gecentreerd rond 27.000 met een normale verdeling en standaarddeviatie van 15.000, met 10.000 datapunten. (We zullen deze termen later meer bespreken, als je er niet bekend mee bent).

# %%
import numpy as np

incomes = np.random.normal(27000, 15000, 10000)
incomes[0:10]  # print first 10 array-elements
# Out:
# array([43754.76058226, 32018.11680533,  8866.52786924, 34257.79246731,
#        14231.11329393, 15091.15073149, 37512.33108887,  2760.86775543,
#        43003.09000308, 46740.9831433 ])

# %% [markdown]
# We gaan de inkomensgegevens segmenteren in 50 buckets en deze plotten als een histogram:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist(incomes, 50)
plt.show()

# %% [markdown]
# ### Opdracht:
#
# Bereken het gemiddelde en de mediaan van het inkomen `incomes`.
#
# Maak gebruik van de `numpy-cheatsheet` (zie bronmateriaal van de module MCL).
#
# NB. Aangezien we een mooie, gelijkmatige verdeling hebben - zie histogram, zou deze ook bijna 27.000 moeten zijn:

# %%
# hier komt jouw code...

# %% [markdown]
# ### Toevoegen van een uitschieter (outlier)
# Nu voegen we het inkomen van Donald Trump toe aan de mix (geschat inkomen: €1.000.000.000) Verdorie inkomensongelijkheid!
#
# ### Opdracht
# Voegtoe het inkomen aan de `incomes` array.

# %%
# hier komt jouw code...

# %% [markdown]
# ### Opdracht
# Bereken wederom het gemiddelde en de mediaan van het inkomen `incomes`.
#
# Wat valt je op?</br>
# (en maak er een notitie van om te onthouden)
#
#
# **Opmerking**:
# median noemt men ook wel een "typisch voorbeeld" van de data-verzameling, en dat is niet altijd het geval met het gemiddelde!

# %%
# hier komt jouw code...

# %% [markdown]
# ---
# ## Oefening Mode
#
# Wederom genereren we een (kunstmatige) dataset van leeftijden van 500 mensen:
# `ages = np.random.randint(18, high=90, size=500)`
#
# ### Opdracht
# Bereken de mode van de leeftijden `ages`. Maak gebruik van de class `stats` uit library `scipy`.

# %%
ages = np.random.randint(18, high=90, size=500)
ages

# %%
# hier komt jouw code...

# %% [markdown]
# ---
# ## Oefening e-commerce data
#
# Hier is code die willekeurige e-commerce gegevens genereert: een reeks van totale bedrag dat per transactie is uitgegeven.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 20.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %% [markdown]
# Bepaal nu het gemiddelde en de mediaan van deze gegevens. Schrijf in het onderstaande codeblok je code en kijk of je resultaat klopt:

# %%
# hier komt jouw code...

# %% [markdown]
# Probeer met de bovenstaande code te spelen zoals toevoegen uitschieters (*outliers*) om hun effect te zien. Maak zowel grote als kleine uitschieters.

# %% [markdown]
# ---
# ## 3. Standaard deviatie en variantie
#
# In statistieken is de standaardafwijking (standaarddeviatie, vaak weergegeven door de kleine Griekse letter sigma σ) een maat die wordt gebruikt om de hoeveelheid variatie of **spreiding** van een reeks gegevenswaarden te kwantificeren.
#
# ![Standaardafwijking](images/stdvar.png)
#
# Een lage standaardafwijking geeft aan dat de gegevenspunten zich meestal in de buurt van het gemiddelde van de set bevinden, terwijl een hoge standaardafwijking aangeeft dat de gegevenspunten over een groter bereik van waarden zijn verdeeld.
#
# In de wetenschap rapporteren veel onderzoekers de standaarddeviatie van experimentele gegevens. Effecten die veel verder dan twee standaardafwijkingen afwijken van wat zou worden verwacht, worden beschouwd als statistisch significant afwijkend (ook wel genoemd *outliers*).
#
# De standaardafwijking is ook belangrijk in de financiële wereld, waarbij de standaardafwijking van het rendement op een belegging een maat is voor de *volatiliteit* van de belegging.
#
# In de financiële markten is de *volatiliteit* de mate van beweeglijkheid van de koers van een aandeel of een ander financieel product zoals een aandelenindex of valuta. Stabiele beursfondsen zoals Unilever en Royal Dutch Shell hebben een vrij lage volatiliteit.

# %% [markdown]
# De standaarddeviatie van een willekeurige variabele, statistische populatie, gegevensset of kansverdeling is de vierkantswortel van zijn variantie. De variantie is het gemiddelde van de kwadratische verschillen van de getallen met het gemiddelde.
#
# **Voorbeeld**</br>
# Wat is de variantie van de dataset (1, 4, 5, 4, 8)?
#
# - bepaal eerst de gemiddelde waarde: (1+4+5+4+8) / 5 = 4.4
# - bepaal het verschil van elke waarde met het gemiddelde: (-3.4, -0.4, 0.6, -0.4, 3.6)
# - bepaal het kwadraat van deze verschilen: (11.56, 0.16, 0.36, 0.16, 12.96)
# - variantie $ σ^2 $ = (11.56 + 0.16 + 0.36 + 0.16 + 12.96) / 5 = 5.04
# - standaardafwijking σ ≈ 2.24

# %% [markdown]
# ---
# ### Oefening inkomens dataset
#
# Genereer wederom een inkomens dataset:
# `incomes = np.random.normal(100.0, 50.0, 10000)`
# en maak een histogram - zie volgende codeblok.
#
# ### Opdracht
#
# Bepaal de standaard deviatie en variance van de inkomens arrary `incomes`. Maak wederom gebruik van de numpy-cheatsheet en de [numpy documentatie](https://numpy.org/doc/stable/index.html) op het web.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()

# standaarddeviatie
# vul hier jouw code in

# variance
# vul hier jouw code in

# %% [markdown]
# Experimenteer met verschillende parameters op de normale functie en kijk welk effect dit heeft op de vorm van de verdeling. Hoe verhoudt die nieuwe vorm zich tot de standaarddeviatie en variantie?
#
# ## Oefening voorbeelddataset
# - neem ook onderstaande voorbeelddataset, plot deze als histogram en bereken de standaarddeviatie en variantie.
# - zijn er outliers?

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

dataset = np.array([1,4,5,4,8])

# histogram, standaarddeviatie & variance
# vul hier in jouw code
